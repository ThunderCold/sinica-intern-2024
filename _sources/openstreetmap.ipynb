# %% [markdown]
# # OpenStreetMap 作業

# %% [markdown]
# ## Overpass API

# %%
import requests
import folium

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = [
"""
[out:json];
area["name:en"="Taipei"];
( 
node["name"="全家便利商店"](area);
 way["name"="全家便利商店"](area);
 rel["name"="全家便利商店"](area);
);
out center;
""",
"""
[out:json];
area["name:en"="Taipei"];
( 
node["name"="7-Eleven"](area);
 way["name"="7-Eleven"](area);
 rel["name"="7-Eleven"](area);
);
out center;
""",
"""
[out:json];
area["name:en"="Taipei"];
( 
node["name"="萊爾富"](area);
 way["name"="萊爾富"](area);
 rel["name"="萊爾富"](area);
);
out center;
""",
"""
[out:json];
area["name:en"="Taipei"];
( 
node["name"="OK超商"](area);
 way["name"="OK超商"](area);
 rel["name"="OK超商"](area);
);
out center;
"""]

response = [requests.get(overpass_url, 
                        params={'data': overpass_query[0]}),
            requests.get(overpass_url, 
                        params={'data': overpass_query[1]}),
            requests.get(overpass_url, 
                        params={'data': overpass_query[2]}),
            requests.get(overpass_url, 
                        params={'data': overpass_query[3]})]

data = [response[0].json(), response[1].json(), response[2].json(), response[3].json()]

# %%
map = folium.Map(location=[25.06, 121.562], zoom_start=12)
color = ['blue', 'green', 'red', 'white']

for i in range(4):
    for element in data[i]['elements']:
        lat = element['lat']
        lon = element['lon']
        name = element.get('tags', {}).get('name')
    
        folium.Marker(
            location=[lat, lon],
            popup=[name,lat,lon],
            icon=folium.Icon(icon='info-sign',color=color[i]),
            tooltip='Click',
            prefix='fa'
        ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f31ec454d7405440d9c0939dc14da85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f31ec454d7405440d9c0939dc14da85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f31ec454d7405440d9c0939dc14da85 = L.map(
#                 &quot;map_3f31ec454d7405440d9c0939dc14da85&quot;,
#                 {
#                     center: [25.06, 121.562],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f830dcfe94d68443ca2ba90594fc2d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3f830dcfe94d68443ca2ba90594fc2d0.addTo(map_3f31ec454d7405440d9c0939dc14da85);
#
#
#             var marker_a39f9e4529be880bcb1b3a0622b2e65a = L.marker(
#                 [25.0284344, 121.5688292],
#                 {&quot;prefix&quot;: &quot;fa&quot;}
#             ).addTo(map_3f31ec454d7405440d9c0939dc14da85);
#
#
#             var icon_2d0adca8ad87927913a25dd1e2fa9c68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a39f9e4529be880bcb1b3a0622b2e65a.setIcon(icon_2d0adca8ad87927913a25dd1e2fa9c68);
#
#
#         var popup_35665431a31281ae4cdc105ada357a5b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e546fbc85b33a296c2154ec1dd6b72f1 = $(`&lt;div id=&quot;html_e546fbc85b33a296c2154ec1dd6b72f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;全家便利商店&#x27;, 25.0284344, 121.5688292]&lt;/div&gt;`)[0];
#                 popup_35665431a31281ae4cdc105ada357a5b.setContent(html_e546fbc85b33a296c2154ec1dd6b72f1);
#
#
#
#         marker_a39f9e4529be880bcb1b3a0622b2e65a.bindPopup(popup_35665431a31281ae4cdc105ada357a5b)
#         ;
#
#
#
#
#             marker_a39f9e4529be880bcb1b3a0622b2e65a.bindTooltip(
#                 `&lt;div&gt;
#                      Click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_645ce05ad3b553a523c2c1200d7c6c4f = L.marker(
#                 [25.0180229, 121.537435],
#                 {&quot;prefix&quot;: &quot;fa&quot;}
#             ).addTo(map_3f31ec454d7405440d9c0939dc14da85);
#
#
#             var icon_0eba946508f968b2129a93c3b9cdf9f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_645ce05ad3b553a523c2c1200d7c6c4f.setIcon(icon_0eba946508f968b2129a93c3b9cdf9f0);
#
#
#         var popup_dc794468507fd9529fca5ab711cff2f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d438520e36fdb8d97ee87903ba56b2d = $(`&lt;div id=&quot;html_9d438520e36fdb8d97ee87903ba56b2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;全家便利商店&#x27;, 25.0180229, 121.537435]&lt;/div&gt;`)[0];
#                 popup_dc794468507fd9529fca5ab711cff2f1.setContent(html_9d438520e36fdb8d97ee87903ba56b2d);
#
#
#
#         marker_645ce05ad3b553a523c2c1200d7c6c4f.bindPopup(popup_dc794468507fd9529fca5ab711cff2f1)
#         ;
#
#
#
#
#             marker_645ce05ad3b553a523c2c1200d7c6c4f.bindTooltip(
#                 `&lt;div&gt;
#                      Click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d06f24a8cc7f1f89052c90ad1070b1f5 = L.marker(
#                 [25.0188254, 121.5334846],
#                 {&quot;prefix&quot;: &quot;fa&quot;}
#             ).addTo(map_3f31ec454d7405440d9c0939dc14da85);
#
#
#             var icon_656a3c6ca01650c7649f6f669f08b225 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d06f24a8cc7f1f89052c90ad1070b1f5.setIcon(icon_656a3c6ca01650c7649f6f669f08b225);
#
#
#         var popup_f288b73c36b93f9d460c31f3babc0eb0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb85bbaad7c0d0a8de001c69417225de = $(`&lt;div id=&quot;html_eb85bbaad7c0d0a8de001c69417225de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;全家便利商店&#x27;, 25.0188254, 121.5334846]&lt;/div&gt;`)[0];
#                 popup_f288b73c36b93f9d460c
